# %%
f
# Out:
#                          Model Name Epoch Training Loss            \
#                                                    mean       std
# 0                         BaseModel     1      1.047989  0.018951
# 1                         BaseModel     2      0.611366  0.009324
# 2                         BaseModel     3      0.601332  0.014382
# 3                         BaseModel     4      0.588644  0.011967
# 4                         BaseModel     5      0.581689  0.008797
# 5                         BaseModel     6      0.578062  0.008231
# 6                         BaseModel     7      0.573716  0.010729
# 7                         BaseModel     8      0.568691  0.008719
# 8                         BaseModel     9      0.562765  0.009427
# 9                         BaseModel    10      0.566928  0.009526
# 10  MultilayerTransformerBlockModel     1      0.876074  0.017723
# 11  MultilayerTransformerBlockModel     2      0.625170  0.013242
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Set up the plot
metrics = ["Training Loss", "Training Accuracy", "Validation Loss", "Validation Accuracy"]
colors = sns.color_palette("tab10", len(df["Model Name"].unique()))
models = df["Model Name"].unique()

fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharex=True)

for i, metric in enumerate(metrics):
    ax = axes[i // 2, i % 2]
    for model, color in zip(models, colors):
        model_data = df[df["Model Name"] == model]
        ax.plot(
            model_data["Epoch"],
            model_data[metric],
            marker='o',
            label=model,
            color=color
        )
    ax.set_title(metric)
    ax.set_xlabel("Epoch")
    ax.set_ylabel(metric)
    ax.legend(title="Model Name")
    ax.grid(True)

plt.tight_layout()
plt.show()
